# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0, 1, 2, 3])
y=np.array([3, 8, 1, 10])

plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([2,3,4,8])
y=np.array([7,6,9,3])

plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0, 1, 2, 3])
y=np.array([3, 8, 1, 10])

plt.subplot(2,1,1)
plt.plot(x,y)

x=np.array([2,3,4,8])
y=np.array([7,6,9,3])

plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([0,1,2,3])
y1=np.array([2,3,4,5])

plt.subplot(2,3,1)
plt.plot(x1,y1)

x2=np.array([1,2,3,4])
y2=np.array([3,4,5,6])

plt.subplot(2,3,2)
plt.plot(x2,y2)

x3=np.array([5,4,3,2])
y3=np.array([5,4,3,2])
plt.subplot(2,3,3)
plt.plot(x3,y3)

x4=np.array([8,7,6,5])
y4=np.array([6,5,4,3])
plt.subplot(2,3,4)
plt.plot(x4,y4)

x5=np.array([8,7,8,4])
y5=np.array([1,7,8,9])
plt.subplot(2,3,5)
plt.plot(x5,y5)

x6=np.array([7,9,2,6])
y6=np.array([1,9,7,8])
plt.subplot(2,3,6)
plt.plot(x6,y6)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0, 1, 2, 3])
y=np.array([3, 8, 1, 10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")

x=np.array([2,3,4,8])
y=np.array([7,6,9,3])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()
