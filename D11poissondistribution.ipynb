# %%
from numpy import random
x=random.poisson(lam=2,size=10)
print(x)
# Out:
# [0 0 0 4 1 2 2 5 2 2]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([0,0,0,4,1,2,2,5,2,2])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_5088\1760953942.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,0,0,4,1,2,2,5,2,2])

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(random.poisson(lam=4,size=100))
plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(loc=50,scale=5,size=1000)  ,hist=False , kde=True , label='normal')
sns.distplot(random.poisson(lam=4,size=1000),hist=False,kde=True,label='poisson')
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_5088\1672158550.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50,scale=5,size=1000)  ,hist=False , kde=True , label='normal')
# C:\Users\Priti\AppData\Local\Temp\ipykernel_5088\1672158550.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.binomial(n=5,p=0.5,size=1000)  ,hist=False , kde=True , label='binomial')
sns.distplot(random.poisson(lam=4,size=1000),hist=False,kde=True,label='poisson')
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_5088\2596935261.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=5,p=0.5,size=1000)  ,hist=False , kde=True , label='binomial')
# C:\Users\Priti\AppData\Local\Temp\ipykernel_5088\2596935261.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...
