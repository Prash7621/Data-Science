# %%
from numpy import random
x=random.normal(size=(2,3))
print(x)
# Out:
# [[ 0.85905288  2.2001114  -2.38687684]
#  [-0.1565789   0.28599229 -0.27179697]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([[ 0.85905288 , 2.2001114 , -2.38687684],
 [-0.1565789 , 0.28599229 , -0.27179697]])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_16872\2448533395.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([[ 0.85905288 , 2.2001114 , -2.38687684],

# %%
from numpy import random
x=random.normal(loc=1 , scale=2 , size=(2,3))
print(x)
# Out:
# [[ 1.57646269  1.34946909 -1.68264938]
#  [ 0.75533518 -2.04402369 -1.08680443]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([[ 1.57646269 , 1.34946909 , -1.68264938] ,
 [ 0.75533518 ,-2.04402369 ,-1.08680443]])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_16872\223864499.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([[ 1.57646269 , 1.34946909 , -1.68264938] ,

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(size=1000),hist=False)
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_16872\889937318.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)
# <Axes: ylabel='Density'>

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
x=random.normal(loc=2 , scale=3 , size=(3,4))
sns.distplot(x)
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_16872\499200065.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
