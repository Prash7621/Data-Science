# %%
from numpy import random
x=random.normal(loc=0,scale=1,size=500)
print(x[:10])
# Out:
# [-1.46784343 -0.64370142  0.04344193  0.65271866  1.07353443  0.5139051
#  -0.93884972  0.73122888  0.37299413 -1.13304579]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([-1.46784343,-0.64370142,0.04344193 ,0.65271866 , 1.07353443 , 0.5139051,
 -0.93884972 , 0.73122888  ,0.37299413 ,-1.13304579])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_1628\3610181324.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([-1.46784343,-0.64370142,0.04344193 ,0.65271866 , 1.07353443 , 0.5139051,

# %%
from numpy import random
x=random.normal(loc=70,scale=10,size=200)

import numpy as np
n=np.mean(x)
print("mean = " , n)
s=np.std(x)
print("standard deviation = " , s)
# Out:
# mean =  70.97879999625101
# standard deviation =  10.304495989393956

# %%
from numpy import random
import numpy as np
x=random.binomial(n=1,p=0.5,size=50)

print("Number of heads obtained : ",np.sum(x))
# Out:
# Number of heads obtained :  25

# %%
from numpy import random
x=random.binomial(n=1,p=1/6,size=100)
print("Number of success : ",np.sum(x))
# Out:
# Number of success :  19

# %%
from numpy import random
c=random.poisson(lam=4,size=60)
print("Number of cars in simulation : " , np.sum(x))
# Out:
# Number of cars in simulation :  19

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([c])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_1628\516589753.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([c])
