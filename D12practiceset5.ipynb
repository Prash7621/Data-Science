# %%
from numpy import random
x=random.uniform(low=5,high=15,size=(3,4))
print(x)
# Out:
# [[13.61601162  9.04319748 11.01660934 11.52907736]
#  [ 8.00777431 13.03922785 13.22127683  7.0161261 ]
#  [14.65271694 13.9629717   6.61061118  5.99291204]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([x])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_3312\1880093450.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([x])

# %%
from numpy import random
a=random.uniform(low=0,high=360,size=10)
print(a)
# Out:
# [342.92942858   8.45047654  34.26160898 302.10017606 246.8087014
#  350.789887   160.56656574 227.10508077 294.13814073 246.26214261]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([a])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_3312\3434936254.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([a])

# %%
from numpy import random
l=random.logistic(loc=0,scale=1,size=(2,5))
print(l)
# Out:
# [[ 1.98167038 -1.71401184 -0.31275887  1.82762158  0.78750303]
#  [-0.80038041 -0.12880656 -0.16501739 -1.13450775 -0.52186904]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([l])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_3312\3237239337.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([l])

# %%
from numpy import random
m=random.logistic(loc=170,scale=10,size=(4,2))
print(m)
# Out:
# [[171.07339099 145.62436961]
#  [158.36019255 152.4342701 ]
#  [194.44594229 153.18205011]
#  [168.90978834 138.40958388]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([m])
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_3312\466015916.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([m])

# %%
from numpy import random
import numpy as np
v=random.multinomial(n=100,pvals=[0.5,0.3,0.2])
print(v[0])
# Out:
# 48

# %%
from numpy import random
import numpy as np
v=random.multinomial(n=100,pvals=[0.5,0.3,0.2])
print(v[1])
# Out:
# 35

# %%
from numpy import random
import numpy as np
v=random.multinomial(n=100,pvals=[0.5,0.3,0.2])
print(v[2])
# Out:
# 19
