# %% [markdown]
# <a href="https://colab.research.google.com/github/Prash7621/Data-Science/blob/main/stock_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %%
import yfinance as yf

# %%
import datetime as dt

# %%
stock="POWERGRID.NS"
start=dt.datetime(2000,1,1)
end=dt.datetime(2025,4,1)

# %%
df=yf.download(stock,start,end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df.head(5)
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    32.545433    35.424702    26.900126    29.051490    855215656
# 2007-10-08    30.879328    33.645365    30.685219    33.645365    126671715
# 2007-10-09    32.982166    33.273327    29.229414    30.895505    116725709
# 2007-10-10    33.289501    33.968879    32.998340    33.839473     67931378
# 2007-10-11    37.009903    38.821577    32.998342    38.821577    106320954

# %%
df.shape
# Out:
# (4310, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4310 entries, 2007-10-05 to 2025-03-28
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4310 non-null   float64
#  1   (High, POWERGRID.NS)    4310 non-null   float64
#  2   (Low, POWERGRID.NS)     4310 non-null   float64
#  3   (Open, POWERGRID.NS)    4310 non-null   float64
#  4   (Volume, POWERGRID.NS)  4310 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 202.0 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4310.000000  4310.000000  4310.000000  4310.000000  4.310000e+03
# mean      84.585687    85.686443    83.500099    84.626182  1.192985e+07
# std       70.943929    71.793451    70.059756    70.938464  2.040232e+07
# min       19.001736    20.312200    17.036039    20.213915  0.000000e+00
# 25%       36.671241    37.229384    36.158135    36.746403  4.868693e+06
# 50%       61.339874    62.201174    60.366227    61.227533  8.479488e+06
# 75%       85.147173    86.046803    84.147976    85.273735  1.375390e+07
# max      356.113861   356.893408   348.074624   354.749603  8.552157e+08

# %%
df=df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("PowerGrid.csv")

# %%
data1=pd.read_csv("PowerGrid.csv")

# %%
data1.head(5)
# Out:
#     Price        Date               Close               High  \
# 0  Ticker         NaN        POWERGRID.NS       POWERGRID.NS
# 1       0  2007-10-05  32.545433044433594   35.4247016342326
# 2       1  2007-10-08   30.87932777404785   33.6453646841474
# 3       2  2007-10-09    32.9821662902832  33.27332717981798
# 4       3  2007-10-10   33.28950119018555  33.96887948189164
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1  26.900126354297335   29.05149029632149     855215656
# 2  30.685219073914716    33.6453646841474     126671715
# 3  29.229413747593593   30.89550520408466     116725709
# 4   32.99834031886197  33.839472943776364      67931378

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=[go.Candlestick(x = data1['Date'], open = data1['Open'],
                                    high = data1['High'],
                                    low = data1['Low'],
                                    close = data1['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from os import access
df=df.drop(['Date'], axis=1)
# Out:
# <ipython-input-19-35d57f691a32>:2: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.head(5)
# Out:
# Price         Close         High          Low         Open       Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0         32.545433    35.424702    26.900126    29.051490    855215656
# 1         30.879328    33.645365    30.685219    33.645365    126671715
# 2         32.982166    33.273327    29.229414    30.895505    116725709
# 3         33.289501    33.968879    32.998340    33.839473     67931378
# 4         37.009903    38.821577    32.998342    38.821577    106320954

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'],label=f'{stock} Closing Price',linewidth=1)
plt.title(f'{stock} Closing Prices over time')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Open'], label=f'{stock} Opening Price' , linewidth=1)
plt.title(f'{stock} Opening Price over time')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
plt.plot(df['High'] , label=f'{stock} High Price' , linewidth=1)
plt.title(f'{stock} High Price over time')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Low'] , label=f'{stock} Low Price',linewidth=1)
plt.title(f'{stock}  low price over time')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Volume'] , label=f'{stock} Volume Price' , linewidth=1)
plt.title(f'{stock} Volume Price over time')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
temp_Data=[10,20,30,40,50,60,70,80,90]
df1=pd.DataFrame(temp_Data)

# %%
df1.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100=df.Close.rolling(100).mean()
ma200=df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'] , label=f'{stock} Close Price' , linewidth=1)
plt.plot(ma100 , label=f'{stock} Moving Average 100 Price' , linewidth=1)
plt.plot(ma200 , label=f'{stock} Moving Average 200 Price' , linewidth=1)
plt.title(f'{stock} Volume Price over time')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ema100=df.Close.ewm(span=100 , adjust=False).mean()
ema200=df.Close.ewm(span=200 , adjust=False).mean()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'] , label=f'{stock} Close Price' , linewidth=1)
plt.plot(ema100 , label=f'{stock} Exp. Moving Average 100 Price' , linewidth=1)
plt.plot(ema200 , label=f'{stock} Exp. Moving Average 200 Price' , linewidth=1)
plt.title(f'{stock} Volume Price over time')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Training and testing
Data_training=pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
Data_testing=pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])
Data_training.shape,Data_testing.shape
# Out:
# ((3017, 1), (1293, 1))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Scaler=MinMaxScaler(feature_range=(0,1))

# %%
data_training_arr=Scaler.fit_transform(Data_training)

# %%
data_training_arr
# Out:
# array([[0.1980862 ],
#        [0.17371823],
#        [0.20447373],
#        ...,
#        [0.88055071],
#        [0.87360106],
#        [0.88810436]])

# %%
data_training_arr.shape
# Out:
# (3017, 1)

# %%
xtrain=[]
ytrain=[]

for i in range(100,data_training_arr.shape[0]):
  xtrain.append(data_training_arr[i-100:i])
  ytrain.append(data_training_arr[i,0])

xtrain,ytrain=np.array(xtrain),np.array(ytrain)

# %%
xtrain.shape
# Out:
# (2917, 100, 1)

# %%
ytrain.shape
# Out:
# (2917,)

# %%
xtrain.shape[1]
# Out:
# 100

# %%
from keras.layers import Dense , LSTM , Dropout
from keras.models import Sequential

# %%
model=Sequential()

model.add(LSTM(units=50 , activation="relu" , return_sequences=True  ,input_shape=(xtrain.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=60 , activation='relu' , return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=80 , activation='relu' , return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(units=100 , activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer="adam" , loss="mean_squared_error")

# %%
model.fit(xtrain,ytrain , epochs=50 , validation_data=(xtrain,ytrain))
# Out:
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 36s 315ms/step - loss: 0.0848 - val_loss: 0.0021
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 36s 262ms/step - loss: 0.0089 - val_loss: 0.0018
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 255ms/step - loss: 0.0084 - val_loss: 0.0021
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 45s 306ms/step - loss: 0.0068 - val_loss: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 37s 258ms/step - loss: 0.0078 - val_loss: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 251ms/step - loss: 0.0068 - val_loss: 0.0026
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 250ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 24s 261ms/step - loss: 0.0054 - val_loss: 9.8700e-04
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 24s 261ms/step - loss: 0.0051 - val_loss: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 40s 251ms/step - loss: 0.0047 - val_loss: 0.0011
# Epoch 11/50
# ...

# %%
past_100_days=Data_testing.tail(100)

# %%
final_df=pd.concat([past_100_days,Data_testing] , ignore_index=True)

# %%
final_df.head(7)
# Out:
# Ticker  POWERGRID.NS
# 0         308.511810
# 1         310.363281
# 2         304.955078
# 3         308.170776
# 4         321.374573
# 5         314.455994
# 6         309.876068

# %%
input_data=Scaler.fit_transform(final_df)

# %%
xtest=[]
ytest=[]

for i in range(100 , input_data.shape[0]):
   xtest.append(input_data[i-100:i])
   ytest.append(input_data[i,0])

xtest,ytest=np.array(xtest),np.array(ytest)

# %%
xtest.shape
# Out:
# (1293, 100, 1)

# %%
ytest.shape
# Out:
# (1293,)

# %%
xtest.shape , ytest.shape
# Out:
# ((1293, 100, 1), (1293,))

# %%
xtest.shape[1]
# Out:
# 100

# %%
y_prd=model.predict(xtest)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step

# %%
y_prd
# Out:
# array([[0.7557672 ],
#        [0.76037526],
#        [0.7559655 ],
#        ...,
#        [0.7270328 ],
#        [0.7358128 ],
#        [0.74561644]], dtype=float32)

# %%
Scaler.scale_
# Out:
# array([0.00339719])

# %%
scale_factor=1/0.00339719
y_prd= y_prd*scale_factor
ytest=ytest*scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(ytest , label="Original Value" , linewidth=1)
plt.plot(y_prd , label="Predicted Value" , linewidth=1)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model.save("StockPrediction.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
